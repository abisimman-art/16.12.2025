# %%
x=5

# %%
print("x")
# Out:
# x

# %%
x='5'
print(x)
# Out:
# 5

# %%
### Heading

# %%
"hello world"
print('hello world')
# Out:
# hello world

# %% [markdown]
# ### heading

# %%
x=5
y=9
print(x+y)
# Out:
# 14

# %%
x=5.23
print(x)
# Out:
# 5.23

# %%
type(x)
# Out:
# float

# %%
shopping_list=["eggs","potato","beet","carrot","milk"]
len(shopping_list)
# Out:
# 5

# %%
shopping_list[3]
# Out:
# 'carrot'

# %%
shopping_list.append("bread")

# %%
shopping_list
# Out:
# ['eggs', 'potato', 'beet', 'carrot', 'milk', 'bread']

# %%
shopping_list[3]="fig"

# %%
shopping_list
# Out:
# ['eggs', 'potato', 'beet', 'fig', 'milk', 'bread']

# %%
shopping_list1=["brush","paste","soap","oil"]
items=[]
items=shopping_list.append(shopping_list1)

# %%
shopping_list
# Out:
# ['eggs',
#  'potato',
#  'beet',
#  'fig',
#  'milk',
#  'bread',
#  ['brush', 'paste', 'soap', 'oil'],
#  ['brush', 'paste', 'soap', 'oil'],
#  ['brush', 'paste', 'soap', 'oil'],
#  ['brush', 'paste', 'soap', 'oil'],
#  ['brush', 'paste', 'soap', 'oil']]

# %%
items

# %%
shopping_list[5]
# Out:
# 'bread'

# %%
shopping_list[-3]
# Out:
# ['brush', 'paste', 'soap', 'oil']

# %%
len(shopping_list)
# Out:
# 11

# %%
str2=["hello python"]

# %%
str2
# Out:
# ['hello python']

# %%
len(str2)
# Out:
# 1

# %%
range(str2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 range(str2)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
str2[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 str2[5]
#
# IndexError: list index out of range

# %%
str3=['hello,python']

# %%
str3
# Out:
# ['hello,python']

# %%
str="hello python"

# %%
str
# Out:
# 'hello python'

# %%
str[2:8]
# Out:
# 'llo py'

# %%
str[:-5]
# Out:
# 'hello p'

# %%
str[-1]
# Out:
# 'n'

# %%
str[-6]
# Out:
# 'p'

# %%
str[:]
# Out:
# 'hello python'

# %%
str[::-3]
# Out:
# 'nt l'

# %%
str[-1:-5]
# Out:
# ''

# %% [raw]
# str[-12:-2]

# %%
str
# Out:
# 'hello python'

# %%
str[-5:-2]
# Out:
# 'yth'

# %%
str[-12:-1]
# Out:
# 'hello pytho'

# %%
str[-1:-10]
# Out:
# ''

# %%
str.count('l')
# Out:
# 2

# %%
str1='hello world'

# %%
str1.count('l')
# Out:
# 3

# %% [raw]
# str.replace(" ","")

# %%
str
# Out:
# 'hello python'

# %%
str.partition("p")
# Out:
# ('hello ', 'p', 'ython')

# %%
str.translate(' ''')
# Out:
# 'hello python'

# %%
str.split('h')
# Out:
# ['', 'ello pyt', 'on']

# %%
2.5+3
# Out:
# 5.5

# %%
2+8
# Out:
# 10

# %% [markdown]
# ### typecasting

# %%
2.55+52
# Out:
# 54.55

# %%
2+"s"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 2+"s"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
2+True
# Out:
# 3

# %%
5-False-True
# Out:
# 4

# %%
2.5*8
# Out:
# 20.0

# %%
2.3*False
# Out:
# 0.0

# %%
int(10)
# Out:
# 10

# %%
float(10)
# Out:
# 10.0

# %%
int(das)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 int(das)
#
# NameError: name 'das' is not defined

# %%
float(mnb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 float(mnb)
#
# NameError: name 'mnb' is not defined

# %%
bool(0)
bool(10)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool("string")
# Out:
# True

# %%
str(True)
# Out:
# 'True'

# %% [markdown]
# ### string concetanation

# %%
str1="abi"
str2="simman"

# %%
str1+str2
# Out:
# 'abisimman'

# %%
str1+" "+str2
# Out:
# 'abi simman'

# %% [markdown]
# ### string membership

# %%
str="happy birthday"

# %%
"th" in str
# Out:
# True

# %%
"s" in str
# Out:
# False

# %%
"sad" in str
# Out:
# False

# %%
"sad" not in str
# Out:
# True

# %% [markdown]
# ### joining the number and string

# %%
print("the value of num is:",5)
# Out:
# the value of num is: 5

# %%
print(f"the value of number is:{5}")
# Out:
# the value of number is:5

# %% [markdown]
# ### arithmetic operator

# %%
13/4
# Out:
# 3.25

# %%
13//4
# Out:
# 3

# %%
13**2
# Out:
# 169

# %%
13*2
# Out:
# 26

# %%
13**5
# Out:
# 371293

# %% [markdown]
# ### comparison operator

# %%
x=20
y=12

# %%
print(x>y)
print(x<y)
print(x>=y)
print(x<=y)
print(x==y)
print(x!=y)
# Out:
# True
# False
# True
# False
# False
# True

# %% [markdown]
# ### logical operators

# %%
x=10
y=6
print(x>y and y<x)
# Out:
# True

# %%
print(x>y and
      y==x)
# Out:
# False

# %%
print(x>y or
      y==x)
# Out:
# True

# %%
print(x<y or
      y==x)
# Out:
# False

# %%
not(x<y)
# Out:
# True

# %%
not(x>y)
# Out:
# False

# %%
not(x==y)
# Out:
# True
